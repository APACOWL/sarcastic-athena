# %%
# !pip install openai

import openai

openai.api_key = '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'

# %%
openai.Completion.create(
    engine="davinci",
    prompt="I miss you"
)
# Out:
# <OpenAIObject text_completion id=cmpl-59PsjXkZYsaENObJE8vg3fvLOr12o at 0x7f9e11a0edd0> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\n(1) I ask a lot of questions and expect you to respond"
#     }
#   ],
#   "created": 1652926125,
#   "id": "cmpl-59PsjXkZYsaENObJE8vg3fvLOr12o",
#   "model": "davinci",
#   "object": "text_completion"
# }
